# %%
# !pip install superset
# !pip install apache-superset
# Out:
# Requirement already satisfied: superset in /usr/local/lib/python3.7/dist-packages (0.30.1)
# Requirement already satisfied: apache-superset in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: bleach<4.0.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.3.1)
# Requirement already satisfied: simplejson>=3.15.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.17.5)
# Requirement already satisfied: flask-talisman in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.8.1)
# Requirement already satisfied: flask-wtf in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.14.3)
# Requirement already satisfied: python-geohash in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.8.5)
# Requirement already satisfied: slackclient==2.5.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (2.5.0)
# Requirement already satisfied: msgpack<1.1,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.0.2)
# Requirement already satisfied: cron-descriptor in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.2.24)
# Requirement already satisfied: tabulate==0.8.9 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.8.9)
# Requirement already satisfied: sqlalchemy-utils<0.37,>=0.36.6 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.36.8)
# Requirement already satisfied: selenium>=3.141.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (4.0.0)
# Requirement already satisfied: backoff>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.11.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.19.1)
# Requirement already satisfied: flask<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.1.4)
# Requirement already satisfied: typing-extensions<4,>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.7.4.3)
# Requirement already satisfied: flask-appbuilder<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.3.4)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (35.0.0)
# Requirement already satisfied: pyarrow<4.1,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (4.0.1)
# Requirement already satisfied: flask-migrate in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.1.0)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.10.1)
# Requirement already satisfied: polyline in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.4.0)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (6.0)
# Requirement already satisfied: gunicorn<20.1,>=20.0.2 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (20.0.4)
# Requirement already satisfied: graphlib-backport in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.0.3)
# Requirement already satisfied: wtforms-json in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.3.3)
# Requirement already satisfied: deprecation<2.2.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (2.1.0)
# Requirement already satisfied: markdown>=3.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.3.4)
# Requirement already satisfied: PyJWT<2,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.7.1)
# Requirement already satisfied: croniter>=0.3.28 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.0.15)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.17.0)
# Requirement already satisfied: pgsanity in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.2.9)
# Requirement already satisfied: flask-caching>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.10.1)
# Requirement already satisfied: pandas<1.3,>=1.2.2 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.2.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from apache-superset) (2.8.2)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.6.0)
# Requirement already satisfied: parsedatetime in /usr/local/lib/python3.7/dist-packages (from apache-superset) (2.6)
# Requirement already satisfied: sqlparse==0.3.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.3.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.4.4)
# Requirement already satisfied: itsdangerous<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.1.0)
# Requirement already satisfied: sqlalchemy!=1.3.21,<1.4,>=1.3.16 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (1.3.24)
# Requirement already satisfied: click<8 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (7.1.2)
# Requirement already satisfied: pyparsing<3.0.0,>=2.4.7 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (2.4.7)
# Requirement already satisfied: humanize in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.5.1)
# Requirement already satisfied: celery!=4.4.1,<5.0.0,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (4.4.7)
# Requirement already satisfied: holidays==0.10.3 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.10.3)
# Requirement already satisfied: cachelib<0.2,>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from apache-superset) (0.1.1)
# Requirement already satisfied: redis in /usr/local/lib/python3.7/dist-packages (from apache-superset) (3.5.3)
# Requirement already satisfied: convertdate in /usr/local/lib/python3.7/dist-packages (from holidays==0.10.3->apache-superset) (2.3.2)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.7/dist-packages (from holidays==0.10.3->apache-superset) (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from holidays==0.10.3->apache-superset) (1.15.0)
# Requirement already satisfied: aiohttp>3.5.2 in /usr/local/lib/python3.7/dist-packages (from slackclient==2.5.0->apache-superset) (3.7.4.post0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>3.5.2->slackclient==2.5.0->apache-superset) (1.7.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>3.5.2->slackclient==2.5.0->apache-superset) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp>3.5.2->slackclient==2.5.0->apache-superset) (5.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>3.5.2->slackclient==2.5.0->apache-superset) (21.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>3.5.2->slackclient==2.5.0->apache-superset) (3.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach<4.0.0,>=3.0.2->apache-superset) (21.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach<4.0.0,>=3.0.2->apache-superset) (0.5.1)
# Requirement already satisfied: pytz>dev in /usr/local/lib/python3.7/dist-packages (from celery!=4.4.1,<5.0.0,>=4.3.0->apache-superset) (2018.9)
# Requirement already satisfied: vine==1.3.0 in /usr/local/lib/python3.7/dist-packages (from celery!=4.4.1,<5.0.0,>=4.3.0->apache-superset) (1.3.0)
# Requirement already satisfied: kombu<4.7,>=4.6.10 in /usr/local/lib/python3.7/dist-packages (from celery!=4.4.1,<5.0.0,>=4.3.0->apache-superset) (4.6.11)
# Requirement already satisfied: billiard<4.0,>=3.6.3.0 in /usr/local/lib/python3.7/dist-packages (from celery!=4.4.1,<5.0.0,>=4.3.0->apache-superset) (3.6.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=3.3.2->apache-superset) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=3.3.2->apache-superset) (2.20)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask<2.0.0,>=1.1.0->apache-superset) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask<2.0.0,>=1.1.0->apache-superset) (2.11.3)
# Requirement already satisfied: marshmallow-enum<2,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (1.5.1)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (0.2.1)
# Requirement already satisfied: Flask-OpenID<2,>=1.2.5 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (1.3.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (2.5.1)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (0.26.1)
# Requirement already satisfied: Flask-JWT-Extended<4,>=3.18 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.25.1)
# Requirement already satisfied: marshmallow<4,>=3 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.14.0)
# Requirement already satisfied: email-validator<2,>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (1.1.3)
# Requirement already satisfied: apispec[yaml]<4,>=3.3 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.3.2)
# Requirement already satisfied: Flask-Login<0.5,>=0.3 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (0.4.1)
# Requirement already satisfied: Flask-Babel<3,>=1 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (2.0.0)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.2.0)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from email-validator<2,>=1.0.5->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (2.10)
# Requirement already satisfied: dnspython>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from email-validator<2,>=1.0.5->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (2.1.0)
# Requirement already satisfied: Babel>=2.3 in /usr/local/lib/python3.7/dist-packages (from Flask-Babel<3,>=1->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (2.9.1)
# Requirement already satisfied: python3-openid>=2.0 in /usr/local/lib/python3.7/dist-packages (from Flask-OpenID<2,>=1.2.5->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.2.0)
# Requirement already satisfied: WTForms in /usr/local/lib/python3.7/dist-packages (from flask-wtf->apache-superset) (2.3.3)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.7/dist-packages (from gunicorn<20.1,>=20.0.2->apache-superset) (57.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask<2.0.0,>=1.1.0->apache-superset) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (4.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4,>=3.0.1->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (0.18.0)
# Requirement already satisfied: amqp<2.7,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from kombu<4.7,>=4.6.10->celery!=4.4.1,<5.0.0,>=4.3.0->apache-superset) (2.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4,>=3.0.1->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (3.6.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3,>=1.2.2->apache-superset) (1.19.5)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from python3-openid>=2.0->Flask-OpenID<2,>=1.2.5->flask-appbuilder<4.0.0,>=3.3.0->apache-superset) (0.7.1)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium>=3.141.0->apache-superset) (0.9.2)
# Requirement already satisfied: urllib3[secure]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium>=3.141.0->apache-superset) (1.26.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium>=3.141.0->apache-superset) (0.19.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium>=3.141.0->apache-superset) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium>=3.141.0->apache-superset) (1.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium>=3.141.0->apache-superset) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium>=3.141.0->apache-superset) (1.1.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium>=3.141.0->apache-superset) (1.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium>=3.141.0->apache-superset) (2021.5.30)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium>=3.141.0->apache-superset) (21.0.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=3.141.0->apache-superset) (0.12.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.7/dist-packages (from convertdate->holidays==0.10.3->apache-superset) (0.5.11)
# Requirement already satisfied: brotli in /usr/local/lib/python3.7/dist-packages (from flask-compress->apache-superset) (1.0.9)
# Requirement already satisfied: alembic>=0.7 in /usr/local/lib/python3.7/dist-packages (from flask-migrate->apache-superset) (1.7.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic>=0.7->flask-migrate->apache-superset) (1.1.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic>=0.7->flask-migrate->apache-superset) (5.2.2)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->apache-superset) (1.52)

# %%
# !pip install echarts-python
# Out:
# Collecting echarts-python
#   Downloading echarts-python-0.1.3.tar.gz (6.5 kB)
# Building wheels for collected packages: echarts-python
#   Building wheel for echarts-python (setup.py) ... done
#   Created wheel for echarts-python: filename=echarts_python-0.1.3-py3-none-any.whl size=6475 sha256=1ff28a8818801e358152182bb2de04227dbfa9e22bf1be58f171d3dc2d0ca881
#   Stored in directory: /root/.cache/pip/wheels/eb/ea/8c/e7541cc7459983659772e29e5d2dfedb333d3ada18c3128576
# Successfully built echarts-python
# Installing collected packages: echarts-python
# Successfully installed echarts-python-0.1.3

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in /usr/local/lib/python3.7/dist-packages (2.3.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh) (21.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from bokeh) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh) (2.8.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh) (5.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh) (3.7.4.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh) (7.1.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh) (2.11.3)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh) (6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh) (1.15.0)

# %%
# !pip install option
# Out:
# Collecting option
#   Downloading option-1.0.3-py3-none-any.whl (11 kB)
# Installing collected packages: option
# Successfully installed option-1.0.3

# %%
import matplotlib.pyplot as plt
import superset as superset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import keras
import csv
import bokeh as bokeh
from matplotlib.colors import LogNorm
import option

from echarts import Echart, Legend, Bar, Axis

from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip", data=tips).set(title='Data Tips\n\n')

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips).set(title='Data Tips\n\n')

# %%
g = sns.relplot(x="total_bill", y="tip", kind="line", data=tips).set(title='Data Tips\n\n')
g.figure.autofmt_xdate()

# %%
sns.relplot(x="total_bill", y="tip", hue="day", kind="line", data=tips).set(title='Data Tips\n\n')

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="time", 
            row="sex", height=3, kind="line", estimator=None, data=tips);

# %%
sns.relplot(x="day", y="tip", kind="line", ci="sd", data=tips).set(title='Data Tips\n\n')

# %%
sns.displot(tips, x="total_bill", hue="sex")

# %%
sns.displot(tips, x="total_bill", hue="time", kind="kde", bw_adjust=.25)

# %%
sns.displot(tips, x="total_bill", y="tip", binwidth=(2, .5), cbar=True)

# %%
sns.displot(tips, x="total_bill", y="tip", kind="kde", levels=[.01, .05, .1, .8])

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.catplot(x="day", y="total_bill", hue="weekend",
            kind="box", dodge=False, data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="sex", kind="bar", data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
from scipy import stats
def quantile_plot(x, **kwargs):
    quantiles, xr = stats.probplot(x, fit=False)
    plt.scatter(xr, quantiles, **kwargs)

g = sns.FacetGrid(tips, col="sex", height=4)
g.map(quantile_plot, "total_bill")
